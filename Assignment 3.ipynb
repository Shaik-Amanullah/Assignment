# %%
 
letters = list('xyz')
a = []
[a.append(letters[i]*j )for i in range(len(letters)) for j in range(1,5)]
print(a)
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %%
 
 letters= list('xyz')
pattern=[]
[pattern.append(letters[i]*j)for j in range(1,5) for i in range(len(letters))]
pattern
# Out:
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']

# %%
 
ls=[1,2,3]
a=[(j,i) for i in ls for j in ls]
print(a)
 
a=[(j,i) for i in range(1,4) for j in range(1,4)]
print(a)
# Out:
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]

# %%
 
matrix = [[2,3,4,5],[3,4,5,6],[4,5,6,7],[5,6,7,8]]
list = [[x+y]for x in range(2,5)for y in range(3)]
t = [[row[i] for row in matrix] for i in range(4)]
print (list+t)
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6], [2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]
